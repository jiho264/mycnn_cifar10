# %% [markdown]
# # My CNN

# %% [markdown]
# ## Dataset loading

# %%
import tensorflow as tf
import tqdm
import cv2
import numpy as np
import matplotlib.pyplot as plt
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Download test

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
assert x_train.shape == (50000, 32, 32, 3)
assert x_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (50000, 1)
assert y_test.shape == (10000, 1)

# %%
print ("Training data:")
print ("Number of examples: ", x_train.shape[0])
print ("Number of channels:",x_train.shape[3]) 
print ("Image size:", x_train.shape[1], x_train.shape[2])
print
print ("Test data:")
print ("Number of examples:", x_test.shape[0])
print ("Number of channels:", x_test.shape[3])
print ("Image size:", x_test.shape[1], x_test.shape[2])
# Out:
# Training data:
# Number of examples:  50000
# Number of channels: 3
# Image size: 32 32
# Test data:
# Number of examples: 10000
# Number of channels: 3
# Image size: 32 32

# %%
plt.subplot(141)
plt.imshow(x_train[0][:][:][:], interpolation="bicubic")
plt.grid(False)
plt.subplot(142)
plt.imshow(x_train[4], interpolation="bicubic")
plt.grid(False)
plt.subplot(143)
plt.imshow(x_train[8], interpolation="bicubic")
plt.grid(False)
plt.subplot(144)
plt.imshow(x_train[12], interpolation="bicubic")
plt.grid(False)
plt.show()

# %% [markdown]
# ## Normalize (traning set 건드린 값으로, test set도 정규화)

# %%
new_x_train = x_train
new_x_test = x_test

_mean = np.mean(x_train)
_std = np.std(x_train)
print(_mean, _std)
new_x_train = (new_x_train - _mean)/_std
new_x_test = (new_x_test - _mean)/_std
_mean = np.mean(new_x_train)
_std = np.std(new_x_train)
print(_mean, _std)
plt.subplot(141)
plt.imshow(x_train[0], interpolation="bicubic")
plt.grid(False)
plt.subplot(142)
plt.imshow(new_x_train[0][:][:], interpolation="bicubic")
plt.grid(False)
plt.show()
# Out:
# 120.70756512369792 64.1500758911213
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -2.5247951877342226e-17 1.0000000000000022

# %% [markdown]
# ## Traning

# %%
model = tf.keras.models.Sequential([
  #tf.keras.layers.Flatten(input_shape=(32, 32,1)),
  tf.keras.layers.Conv2D(filters=128, kernel_size=2, padding='same', strides=1, activation='relu', input_shape=(32,32,3)),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', strides=1, activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=1),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', strides=1, activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

tf.keras.utils.plot_model(model, to_file='model02.png', show_shapes=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       1664
#
#  dropout_6 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        32832
#
#  max_pooling2d_4 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 31, 31, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 31, 31, 32)        8224
#
#  max_pooling2d_5 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 15, 15, 32)        0
#
#  flatten_2 (Flatten)         (None, 7200)              0
#
#  dense_4 (Dense)             (None, 512)               3686912
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 3,734,762
# Trainable params: 3,734,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
val_scaled = new_x_test
val_target = y_test

history = model.fit(new_x_train, y_train, batch_size=256, epochs=15, validation_data=(val_scaled, val_target))
model.evaluate(new_x_test, y_test, batch_size=32, verbose=2)
# Out:
# Epoch 1/15
# 196/196 [==============================] - 10s 47ms/step - loss: 1.6446 - accuracy: 0.4129 - val_loss: 1.3423 - val_accuracy: 0.5323
# Epoch 2/15
# 196/196 [==============================] - 9s 46ms/step - loss: 1.1862 - accuracy: 0.5777 - val_loss: 1.1020 - val_accuracy: 0.6092
# Epoch 3/15
# 196/196 [==============================] - 9s 47ms/step - loss: 0.9983 - accuracy: 0.6453 - val_loss: 0.9733 - val_accuracy: 0.6531
# Epoch 4/15
# 196/196 [==============================] - 9s 44ms/step - loss: 0.8537 - accuracy: 0.6969 - val_loss: 0.9043 - val_accuracy: 0.6780
# Epoch 5/15
# 196/196 [==============================] - 9s 43ms/step - loss: 0.7453 - accuracy: 0.7367 - val_loss: 0.8049 - val_accuracy: 0.7127
# Epoch 6/15
# 196/196 [==============================] - 9s 44ms/step - loss: 0.6538 - accuracy: 0.7688 - val_loss: 0.7960 - val_accuracy: 0.7252
# Epoch 7/15
# 196/196 [==============================] - 9s 46ms/step - loss: 0.5659 - accuracy: 0.8008 - val_loss: 0.7961 - val_accuracy: 0.7238
# Epoch 8/15
# 196/196 [==============================] - 9s 46ms/step - loss: 0.4807 - accuracy: 0.8302 - val_loss: 0.8023 - val_accuracy: 0.7252
# Epoch 9/15
# 196/196 [==============================] - 9s 45ms/step - loss: 0.4156 - accuracy: 0.8524 - val_loss: 0.8184 - val_accuracy: 0.7359
# Epoch 10/15
# 196/196 [==============================] - 9s 44ms/step - loss: 0.3569 - accuracy: 0.8731 - val_loss: 0.8625 - val_accuracy: 0.7329
# Epoch 11/15
# 196/196 [==============================] - 9s 46ms/step - loss: 0.3008 - accuracy: 0.8921 - val_loss: 0.9095 - val_accuracy: 0.7259
# Epoch 12/15
# 196/196 [==============================] - 9s 47ms/step - loss: 0.2636 - accuracy: 0.9061 - val_loss: 0.9360 - val_accuracy: 0.7344
# Epoch 13/15
# 196/196 [==============================] - 9s 46ms/step - loss: 0.2251 - accuracy: 0.9201 - val_loss: 1.0110 - val_accuracy: 0.7269
# Epoch 14/15
# 196/196 [==============================] - 9s 46ms/step - loss: 0.2111 - accuracy: 0.9250 - val_loss: 0.9889 - val_accuracy: 0.7296
# Epoch 15/15
# 196/196 [==============================] - 9s 46ms/step - loss: 0.1811 - accuracy: 0.9362 - val_loss: 1.0388 - val_accuracy: 0.7319
# 313/313 - 1s - loss: 1.0388 - accuracy: 0.7319 - 1s/epoch - 4ms/step
# [1.0387980937957764, 0.7318999767303467]

# %%
plt.subplot(221)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
plt.subplot(222)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()

# %%
model.save("_mymodel01")
